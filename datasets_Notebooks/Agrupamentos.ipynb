# %%
#Manipulação de dados

#importando biblioteca Pandas
import pandas as pd

#Leitura dos arquivos
df = pd.read_excel("produtos.xlsx")
df
# Out:
#               NomeCat  IDProduto   CodProd  \
# 0         Abraçadeira    6217460  170627.0
# 1          Acessórios    6219164  370780.0
# 2          Acessórios    6216370  453674.0
# 3          Acessórios    6216466  453691.0
# 4          Acessórios    6139985  453901.0
# ..                ...        ...       ...
# 410  Válvula Retenção    6218390  453592.0
# 411  Válvula Retenção    6218392  453593.0
# 412       Varredeiras    6217445  454327.0
# 413       Varredeiras    6217446  453934.0
# 414       Varredeiras    6217382  450782.0
#
#                                               NomeProd  Peso  Estoque  \
# 0    Abraçadeira rosca sem fim AE 913, 3/8" a 1/2",...     9        1
# 1    Adaptador SDS Plus p/ Mandril de 1/2 P HTOM 17257     5        1
# 2           Aplicador de Detergente - Karcher 93020540   175        1
# 3    Bico Turbo Simples  04 P/HD585 HD5/12 HD6/15 H...   553        1
# 4    Bocal com Cerdas para Limpadoras a Vapor  - Ka...   178        2
# ..                                                 ...   ...      ...
# 410       Válvula Corta Chama RG VCFN-RG Condor 407789    12        1
# 411       Válvula Corta Chama RO VCFN-RO Condor 407790    12        1
# 412  Varredeira de piso manual compacta,produção de...   264        1
# 413  Varredeira de piso manual Residencial com prod...   114        1
# 414             Varredeira KM 70/15 C Karcher 15171510    20        1
#
#      Disponivel  Preco  Lancamento  EmDestaque  IDsFiltroItem
# 0          True   1.43       False        True       154994.0
# 1          True   0.00       False        True       154998.0
# 2          True   0.00       False        True       154984.0
# 3          True   0.00       False        True       154984.0
# 4          True   0.00       False        True       154984.0
# ..          ...    ...         ...         ...            ...
# 410        True   0.00       False        True       155007.0
# 411        True   0.00       False        True       155007.0
# 412        True   0.00       False        True       154984.0
# 413        True   0.00       False        True       154984.0
# 414        True   0.00       False        True       154984.0
#
# [415 rows x 11 columns]

# %%
#informações estatísticas
df.describe()
# Out:
#           IDProduto       CodProd          Peso     Estoque          Preco  \
# count  4.150000e+02  3.340000e+02    415.000000  415.000000     415.000000
# mean   6.220194e+06  1.895335e+10    637.395181    3.344578   31088.928747
# std    3.698048e+04  2.445579e+11   4879.848222    7.514515   94770.346134
# min    6.139176e+06  1.668500e+04      0.000000    0.000000       0.000000
# 25%    6.214702e+06  4.501042e+05      0.000000    1.000000       0.000000
# 50%    6.217940e+06  4.526850e+05     25.000000    1.000000       0.000000
# 75%    6.253618e+06  4.539400e+05    157.000000    1.000000   31357.000000
# max    6.268328e+06  3.165141e+12  93447.000000   50.000000  975572.000000
#
#        IDsFiltroItem
# count     289.000000
# mean   154987.411765
# std         8.856495
# min    154981.000000
# 25%    154981.000000
# 50%    154983.000000
# 75%    154994.000000
# max    155014.000000

# %%
#Agrupamentos por categoria
df.groupby('NomeCat')['Estoque'].sum()
# Out:
# NomeCat
# Abraçadeira                    1
# Acessórios                   220
# Alicates                      17
# Arames                         2
# Arcos de Serra                 1
# Aspiradores                   13
# Bico de Corte                  5
# Bolsa e Mochila                2
# Carregador de Bateria          9
# Chaves Ajustáveis              4
# Cinta Amarração Catraca        8
# Cortador de Metal              5
# Disco Flap                   110
# Disco de Corte               200
# Disco de Desbate             200
# Disco de Lixa                 40
# Eletrodos                      8
# Esmerilhadeira                28
# Ferramentas Bateria           60
# Furadeira e Parafusadeira     58
# Guincho Elétrico               2
# Jogos de Chaves               17
# Kits                           4
# Lav. e Sec. de Pisos          13
# Lavadoras de Alta Pressão     44
# Limpadora Extratora            6
# Limpadora a vapor              4
# Lixadeira                     21
# Lona                           4
# Macaco Hidráulico             11
# Mangueira                      2
# Martelete Demolidor            6
# Martelete Perfurador          69
# Martelos e Marretas            4
# Maçarico                       1
# Multímetro                    15
# Máquina Solda Mig              7
# Máquina de Pintura             2
# Máscara de Solda               2
# Níveis a Laser                 6
# Pistola para Pintura           7
# Plaina                         6
# Politriz                      18
# Regulador Pressão              3
# Retifica                      17
# Retificador/Inversor           5
# Serra Circular                 7
# Serra Mármore                 33
# Serra Tico-Tico               30
# Serra de Esquadria             3
# Soprador                      16
# Talha Alavanca                 1
# Tocha para Solda               3
# Transformador de Solda         1
# Varredeiras                    3
# Válvula Retenção               4
# Name: Estoque, dtype: int64

# %%
#Ordenando o conjunto de dados
df.sort_values("Estoque", ascending=False).head(10)
# Out:
#                  NomeCat  IDProduto   CodProd  \
# 122       Disco de Corte    6206765  451406.0
# 127     Disco de Desbate    6206833  317513.0
# 121       Disco de Corte    6206767  317537.0
# 120       Disco de Corte    6206764  317525.0
# 123       Disco de Corte    6206766  451407.0
# 124     Disco de Desbate    6206831  451408.0
# 125     Disco de Desbate    6206827  451409.0
# 126     Disco de Desbate    6206834  317501.0
# 159  Ferramentas Bateria    6213067  452941.0
# 41            Acessórios    6214726  306492.0
#
#                                               NomeProd  Peso  Estoque  \
# 122  Disco de Corte para Metal 115mm x 2,5mm x 22,2...     6       50
# 127  Disco de Desbaste para Inox 180mm x 6,4mm x 22...     4       50
# 121  Disco de Corte para Inox 180mm x 2,0mm x 22,23...     2       50
# 120  Disco de Corte para Inox 115mm x 2,0mm x 22,23...     6       50
# 123  Disco de Corte para Metal 180mm x 3,0mm x 22,2...     2       50
# 124  Disco de Debaste Para Metal 115mm x 6,0mm x 22...     2       50
# 125  Disco de Debaste para Metal 180mm x 6,0mm x 22...     4       50
# 126  Disco de Desbaste para Inox 115mm x 6,4mm x 22...     2       50
# 159  Furadeira/Parafusadeira a Bateria 12V GSR 1000...   172       20
# 41        Mandril 1/2 Pol. com Furo - Bosch 9617085001    56       20
#
#      Disponivel    Preco  Lancamento  EmDestaque  IDsFiltroItem
# 122        True    292.0       False        True       154981.0
# 127        True   1076.0       False        True       154981.0
# 121        True   1048.0       False        True       154981.0
# 120        True    626.0       False        True       154981.0
# 123        True    472.0       False        True       154981.0
# 124        True    393.0       False        True       154981.0
# 125        True    724.0       False        True       154981.0
# 126        True    629.0       False        True       154981.0
# 159        True  32619.0       False        True       154981.0
# 41         True   2977.0       False        True       154981.0
